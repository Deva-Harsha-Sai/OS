# %%
import sqlite3

# %%
connector = sqlite3.connect(/content/CSM_B")

# %%
cursor = connector.cursor()

# %%
cursor.execute("SELECT * FROM STUDENT")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-8-ed6d405eb0dd> in <cell line: 1>()
# ----> 1 cursor.execute("SELECT * FROM STUDENT")
#
# OperationalError: no such table: STUDENT

# %%
for d in cursor.fetchall():
  print(d)
# Out:
# ('21AG1A6665', 'Aluvala Poojitha', 7032975491)
# ('21AG1A6666', 'Andugula Sai Nikhil', 9347387899)
# ('21AG1A6667', 'Anireddy Preetham Reddy', 9100681177)
# ('21AG1A6668', 'Anugu Srija Reddy', 9866666607)
# ('21AG1A6669', 'Ayushman Sharma', 7993156420)
# ('21AG1A6670', 'Bandari Rana Sagar', 8309586849)
# ('21AG1A6671', 'Bandaru Sathish Kumar', 8688812173)
# ('21AG1A6672', 'Basupally Nuthana', 9381798994)
# ('21AG1A6673', 'Bethi Pavan Sai', 8520824502)
# ('21AG1A6674', 'Bijili Pavan Kalyan', 9390472870)
# ('21AG1A6675', 'Boorugu Bharath Kumar', 9154809928)
# ('21AG1A6676', 'Chirra Rishitha', 6304568974)
# ('21AG1A6677', 'Devalapalli Aishwarya', 8885651942)
# ('21AG1A6678', 'Dharavath Vigneshwar', 7013744335)
# ('21AG1A6679', 'Dinne Police Shashank Reddy', 7569126728)
# ('21AG1A6680', 'Dontharaboina Shiva Prasad', 8688865863)
# ('21AG1A6681', 'G Harshith Kumar', 7997013408)
# ('21AG1A6682', 'Gonu Swetha', 9393636326)
# ('21AG1A6683', 'Goshika Poojitha', 7207806340)
# ...

# %%
cursor.execute("SELECT * FROM STUDENT LIMIT 20")
for d in cursor.fetchall():
  print(d)
# Out:
# ('21AG1A6665', 'Aluvala Poojitha', 7032975491)
# ('21AG1A6666', 'Andugula Sai Nikhil', 9347387899)
# ('21AG1A6667', 'Anireddy Preetham Reddy', 9100681177)
# ('21AG1A6668', 'Anugu Srija Reddy', 9866666607)
# ('21AG1A6669', 'Ayushman Sharma', 7993156420)
# ('21AG1A6670', 'Bandari Rana Sagar', 8309586849)
# ('21AG1A6671', 'Bandaru Sathish Kumar', 8688812173)
# ('21AG1A6672', 'Basupally Nuthana', 9381798994)
# ('21AG1A6673', 'Bethi Pavan Sai', 8520824502)
# ('21AG1A6674', 'Bijili Pavan Kalyan', 9390472870)
# ('21AG1A6675', 'Boorugu Bharath Kumar', 9154809928)
# ('21AG1A6676', 'Chirra Rishitha', 6304568974)
# ('21AG1A6677', 'Devalapalli Aishwarya', 8885651942)
# ('21AG1A6678', 'Dharavath Vigneshwar', 7013744335)
# ('21AG1A6679', 'Dinne Police Shashank Reddy', 7569126728)
# ('21AG1A6680', 'Dontharaboina Shiva Prasad', 8688865863)
# ('21AG1A6681', 'G Harshith Kumar', 7997013408)
# ('21AG1A6682', 'Gonu Swetha', 9393636326)
# ('21AG1A6683', 'Goshika Poojitha', 7207806340)
# ...

# %%
cursor.execute("SELECT * FROM STUDENT LIMIT 20 OFFSET 20")
for d in cursor.fetchall():
  print(d)
# Out:
# ('21AG1A6685', 'Guniganti Ashritha', 7981252114)
# ('21AG1A6686', 'Gurijala Praveena', 8074720214)
# ('21AG1A6687', 'K Roja', 9182513557)
# ('21AG1A6688', 'Kandela Chandana', 6301770828)
# ('21AG1A6689', 'Kandhi Abhinay', 8074287376)
# ('21AG1A6690', 'Kanraj Dhanush', 9392964259)
# ('21AG1A6691', 'Karnati Shiva Kumar', 9392790917)
# ('21AG1A6692', 'Kodikanti Vinay', 9014056124)
# ('21AG1A6693', 'Kotla Pranay Teja', 7287072330)
# ('21AG1A6694', 'Kovuru Abid', 7799277558)
# ('21AG1A6695', 'Kunthavath Shivashankar', 8374451550)
# ('21AG1A6696', 'Kuppi Reddy Nikitha', 9652083981)
# ('21AG1A6697', 'Kusuma Sowmya', 9705885179)
# ('21AG1A6698', 'Macharla Dhivija', 7416441078)
# ('21AG1A6699', 'Manne Sreeja', 9951936472)
# ('21AG1A66A0', 'Mannem Dinesh Reddy', 8712309608)
# ('21AG1A66A1', 'Medi Raghu Vamshi', 9391700949)
# ('21AG1A66A2', 'Meesala Chandhu', 9398221214)
# ('21AG1A66A3', 'Muskaan Thabassum', 9390686462)
# ('21AG1A66A4', 'Nangunuri Deva Harsha Sai', 9705432012)

# %%
cursor.execute("SELECT * FROM STUDENT LIMIT 20 OFFSET 40")
for d in cursor.fetchall():
  print(d)
# Out:
# ('21AG1A66A5', 'Pagidimari Aravind', 9491533209)
# ('21AG1A66A6', 'Pakide Kavya', 6303138585)
# ('21AG1A66A7', 'Paruchuri Prem Sai', 8500577590)
# ('21AG1A66A8', 'Pinnapureddy Bhanuprakash Reddy', 7386431834)
# ('21AG1A66A9', 'Pinninti Manikanth Reddy', 9515720778)
# ('21AG1A66B0', 'Rachha Jaideep', 7993573384)
# ('21AG1A66B1', 'Ravula Shiva Rajesh', 9666569493)
# ('21AG1A66B2', 'S Bharath Reddy', 6281034216)
# ('21AG1A66B3', 'Saganti Akhila', 9347032211)
# ('21AG1A66B4', 'Sagi Amrutha Lahari', 7794064948)
# ('21AG1A66B5', 'Sahil Srivastava', 9949316488)
# ('21AG1A66B6', 'Samala Abhilash', 9515081296)
# ('21AG1A66B7', 'Setty Yogitha', 9515739355)
# ('21AG1A66B8', 'Shaik Habeeb', 6300163597)
# ('21AG1A66B9', 'Siddhant Rajesh Bolenwar', 9579143720)
# ('21AG1A66C0', 'Taduri Harshith Reddy', 9676210774)
# ('21AG1A66C1', 'Takkalapally Sai Mahesh', 8247554261)
# ('21AG1A66C2', 'Tam Tam Venkatesh', 7337453064)
# ('21AG1A66C3', 'Toomu Harika', 7671978172)
# ...

# %%
cursor.execute("SELECT * FROM STUDENT LIMIT 20 OFFSET 60")
for d in cursor.fetchall():
  print(d)
# Out:
# ('21AG1A66C5', 'Vantala Varun', 7702796428)
# ('21AG1A66C6', 'Vongaveti Revathi Chandrika', 7780147106)
# ('21AG1A66C7', 'Vyapare Karthik Kumar', 9381987828)
# ('21AG1A66C8', 'Yarradla Vivek Reddy', 9381551592)
# ('22AG5A6608', 'Bhukya Sahith', 9100670717)
# ('22AG5A6609', 'Udugundla Praveen', 7729806574)
# ('22AG5A6610', 'Som Narendar', 6302469887)
# ('22AG5A6611', 'R Srujana', 8179841497)
# ('22AG5A6612', 'Chattu Sindhu Sri', 7036860160)
# ('22AG5A6613', 'Olluru Sakshith', 9121881227)

# %%
cursor.execute("SELECT * FROM STUDENT WHERE NAME LIKE '%HARSHA%'")
for d in cursor.fetchall():
  print(d)
# Out:
# ('21AG1A66A4', 'Nangunuri Deva Harsha Sai', 9705432012)

# %%
cursor.execute("SELECT * FROM STUDENT WHERE NAME LIKE '%HARSHITH%'")
for d in cursor.fetchall():
  print(d)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-5-44a9f0c693c8> in <cell line: 1>()
# ----> 1 cursor.execute("SELECT * FROM STUDENT WHERE NAME LIKE '%HARSHITH%'")
#       2 for d in cursor.fetchall():
#       3   print(d)
#
# OperationalError: no such table: STUDENT

# %%
cursor.execute("UPDATE STUDENT SET ROLLNO = '69' WHERE ROLLNO = '21AG1A6669'")

# %%
#KNN K nearest neighbors
#import the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier

# %%
data = load_iris()
data['feature_names']
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
data['target_names']
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
#Extracting data from a database
import sqlite3

# %%
connector = sqlite3.connect("mydb.db")

# %%
connector.execute("CREATE TABLE STUDENTS(ID INT PRIMARY KEY, NAME VARCHAR(30));")

# %%
cursor = connector.cursor()

# %%
cursor.execute("INSERT INTO STUDENTS (ID,NAME) VALUES(3,'MR.CAKE');")

# %%
result = cursor.execute("SELECT * FROM STUDENTS")

# %%
for i in result:
  print(i)
# Out:
# (1, 'HARSHA')
# (2, 'HARSHITH')
# (3, 'MR.CAKE')

# %%
RES  = cursor.execute("SELECT NAME FROM STUDENTS")
for i in RES:
  print(i)
# Out:
# ('HARSHA',)
# ('HARSHITH',)
# ('MR.CAKE',)

# %%
#KNN
